# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
seed = 1234
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
value=pd.read_csv('/content/drive/My Drive/UTS_BD/Maxim.csv', sep=';', encoding='utf-8')
value.content=value.content.astype(str)
value.head()
# Out:
#             userName  score                at  \
# 0       Dina Resiana    2.0  27/11/2022 08.56
# 1        rahmi aulia    1.0  27/11/2022 08.23
# 2          tavip vip    1.0  27/11/2022 06.10
# 3    fitriyah hoirus    1.0  27/11/2022 05.54
# 4  Supriatna Adikoko    1.0  27/11/2022 04.01
#
#                                              content Kategori
# 0  Kecewa padahal saya yg nunggu,pas sampai lokas...  Negatif
# 1  Alhamdulillah saya senang sekali belanja pake ...  Negatif
# 2  Aplikasi butut !! Bikin jengkel..!! Manajemen ...  Negatif
# 3  Maxim emang murah. tapi ga bisa ngecancel. sy ...  Negatif
# 4  Murah nya ok. Cuman maps nya. Saya sampe salah...  Negatif

# %%
# Case - Proses konversi huruf yang ada menjadi huruf lowercase atau huruf kecil
import re
def casefolding(content):
    content = content.lower()
    content = content.strip(" ")
    content = re.sub(r'[?|$|.|!2_:")(-+,]','', content)
    return content
value['content'] = value['content'].apply(casefolding)
value.head(100)
# Out:
#              userName  score                at  \
# 0        Dina Resiana    2.0  27/11/2022 08.56
# 1         rahmi aulia    1.0  27/11/2022 08.23
# 2           tavip vip    1.0  27/11/2022 06.10
# 3     fitriyah hoirus    1.0  27/11/2022 05.54
# 4   Supriatna Adikoko    1.0  27/11/2022 04.01
# ..                ...    ...               ...
# 95       Try Silviani    1.0  16/11/2022 08.04
# 96         Mey Wuaten    5.0  16/11/2022 08.02
# 97       Ricky Ardian    1.0  16/11/2022 07.55
# 98       Faizan matin    4.0  16/11/2022 06.14
# 99         Zul - uncu    4.0  16/11/2022 04.46
#
#                                               content Kategori
# 0   kecewa padahal saya yg nunggupas sampai lokasi...  Negatif
# 1   alhamdulillah saya senang sekali belanja pake ...  Negatif
# 2   aplikasi butut  bikin jengkel manajemen juga j...  Negatif
# 3   maxim emang murah tapi ga bisa ngecancel sy pe...  Negatif
# 4   murah nya ok cuman maps nya saya sampe salah p...  Negatif
# ..                                                ...      ...
# 95  harga maxim tidak sesuai aplikasi kalau alasan...  Negatif
# 96  tarif murah dibanding ojol lain cuma mapsnya k...  Positif
# 97  sejauh ini semua baik tapi sangat di sayangkan...  Negatif
# 98  bagus untuk layanannya dan harganyatapi ada ku...  Positif
# 99  applikasi kacau fitur applikasi kurang lengkap...  Positif
#
# [100 rows x 5 columns]

# %%
# Tokenizing - Proses pengurutan kata
def token(content):
    nstr = content.split(' ')
    dat= []
    a = -1
    for hu in nstr:
        a = a + 1
    if hu == '':
        dat.append(a)
    p = 0
    b = 0
    for q in dat:
        b = q - p
        del nstr[b]
        p = p + 1
    return nstr
value['content'] = value['content'].apply(token)
value.head(10)
# Out:
#                  userName  score                at  \
# 0            Dina Resiana    2.0  27/11/2022 08.56
# 1             rahmi aulia    1.0  27/11/2022 08.23
# 2               tavip vip    1.0  27/11/2022 06.10
# 3         fitriyah hoirus    1.0  27/11/2022 05.54
# 4       Supriatna Adikoko    1.0  27/11/2022 04.01
# 5  Desrin vrisnatal sarly    4.0  27/11/2022 00.36
# 6         Petrus Tanituru    5.0  27/11/2022 00.00
# 7            Bayu Septian    4.0  26/11/2022 23.44
# 8                kikie 08    5.0  26/11/2022 16.01
# 9            Ina Tuasikal    1.0  26/11/2022 15.25
#
#                                              content Kategori
# 0  [kecewa, padahal, saya, yg, nunggupas, sampai,...  Negatif
# 1  [alhamdulillah, saya, senang, sekali, belanja,...  Negatif
# 2  [aplikasi, butut, , bikin, jengkel, manajemen,...  Negatif
# 3  [maxim, emang, murah, tapi, ga, bisa, ngecance...  Negatif
# 4  [murah, nya, ok, cuman, maps, nya, saya, sampe...  Negatif
# 5  [sangat, baiktapi, saran, saya, kalau, bisa, p...  Positif
# 6  [sangat, cepay, dan, tepat, intinya, maxim, sa...  Positif
# 7  [maxim, sementara, ini, masih, yang, terbaik, ...  Positif
# 8  [utk, ongkosnya, murah, dibanding, aplikator, ...  Positif
# 9  [kecewa, sama, kebijakan, dari, maxim, sekrang...  Negatif

# %%
#Filtering - Proses penghilangan kata - kata yang tidak penting 
import nltk #Natural Language Toolkit
nltk.download('stopwords') # Menghapus kata kata yang tidak penting seperti yang, ia, nya, dsb
from nltk.corpus import stopwords

def stopword_removal(Neighbourhood):
    filtering = stopwords.words('indonesian','english')
    x= []
    value = []
    def myFunc(x):
        if x in filtering : 
            return False
        else:
            return True
    fit = filter(myFunc, Neighbourhood)
    for x in fit:
        value.append(x)
        return value
value['content'] = value['content'].apply(stopword_removal)
value.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#             userName  score                at          content Kategori
# 0       Dina Resiana    2.0  27/11/2022 08.56         [kecewa]  Negatif
# 1        rahmi aulia    1.0  27/11/2022 08.23  [alhamdulillah]  Negatif
# 2          tavip vip    1.0  27/11/2022 06.10       [aplikasi]  Negatif
# 3    fitriyah hoirus    1.0  27/11/2022 05.54          [maxim]  Negatif
# 4  Supriatna Adikoko    1.0  27/11/2022 04.01          [murah]  Negatif

# %%
#Steaming - Proses pengambilan kata dasar pada susunan kalimat
# !pip install Sastrawi
from sklearn.pipeline import Pipeline
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def stemming(content):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    do = []
    for w in content:
        dt = stemmer.stem(w)
        do.append(dt)
    d_clean=[]
    d_clean= " ".join(do)
    print(d_clean)
    return d_clean
value['content'] = value['content'].apply(stemming)

value.to_csv('data_clean.csv',index=False)
value_clean = pd.read_csv('data_clean.csv', encoding='latin1')
value_clean.head()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)
# kecewa
# alhamdulillah
# aplikasi
# maxim
# murah
# baiktapi
# cepay
# maxim
# utk
# kecewa
# harga
# tampil
# driver
# cari
# aplikasi
# tolong
#
# tarif
# aplikasi
# harga
# tarif
# alam
# maxim
# bingungsetelah
# bagus
# aplikasi
# harga
# bug
# lumayan
# alamat
# login
# map
# maxim
# tarif
# layan
# sistem
# oke
# orang
# kali
# maxim
# alhamdulilah
# error
# maxim
# order
# layan
# kacau
# sya
# baik
# aplikasi
# harga
# bagus
# aplikasi
# tolong
# nya
# app
# maxim
# aplikasi
# parah
# bantu
# apk
# driver
# mapsnya
# maap
# sumpah
# order
# bagus
# layan
# komplain
# maxim
# maxim
# jujur
# terimakasih
# titik
# tlg
# harga
# kasih
# harga
# kasih
# mohon
# tlg
# overall
# kecewa
# order
# driver
# butuh
# tarif
# aplikasi
# jelek
# bagus
# fitur
# udah
# 3
# layan
# maxim
# harga
# harga
# tarif
# sayang
# bagus
# applikasi
# makasih
# bugnya
# aplikasi
# aplikasi
# map
# mohon
# maps
# harap
# ramah
# udh
# tolong
# driver
# past
# biaya
# kecewa
# ajung
# sy
# alam
# kesan
# aplikasi
# tolong
# aplikasi
# harga
# guna
# tolong
# pake
# layan
# maxim
# prihatin
# kecewa
# perbahariu
# tolong
# tarif
# ajarin
# aplikasi
# kalo
# errorrr
# halo
# hai
# maaf
# turun
# oknum
# kecewa
# drivernya
# order
# alhamdulillah
# murah
# map
# aplikasi
# aplikasi
# transportasi
# map
# bapak
# alam
# update
# maxim
# apilkasi
# driver
# aplikasi
# layan
# murah
# kirim
# dtingkatkan
# susah
# order
# applikasi
# ga
# tes
# aplikasi
# apliaksinya
# maxim
# cari
# murah
# apl
# kali
# aneh
# tunggu
# maxim
# tolong
# suka
# lokasi
# murah
# buruk
# udh
# tolong
# lengkap
# driver
# aplikasi
# cepat
# aplikasi
# hallo
# versi
# turunin
# posisi
# gimana
# tolong
# saran
# horor
# tolong
# kurang
# baik
# harga
# tolong
# sesuai
# parahhhh
# kali
# murah
# kritik
# maps
# sistem
# sebenernya
# mohon
# maxim
# murah
# murah
# aplikasi
# tabah
# alamat
# 1
# driver
# bangga
# gue
# maaf
# titik
# bagus
# kemudi
# maxim
# alhamdulillah
# mohon
# aplikasi
# sdh
# kesan
# harga
# tolong
# maxim
# mapsnya
# driver
# min
# parahhh
# guna
# admind
# simpel
# transport
# ni
# aplikasi
# skrang
# mantap
# driver
# guna
# bagus
# jelek
# mohon
# good
# mohon
# layan
# kali
# aplikasi
# abang
# harga
# tolong
# tolong
# order
# tingkat
# guna
# tolong
# asa
# puas
# maps
# sulit
# tolong
# merchant
# mohon
# aplikasi
# terima
# parah
# suka
# habis
# maxim
# aplikasi
# senang
# kapok
# maxim
# layan
# mas
# layan
# baik
# good
# murah
# gak
# aplikasi
# maxim
# harga
# maaf
# kecewa
# maaf
# upgrade
# maxim
# tolong
# aplikasi
# guna
# tolong
# kode
# driver
# upgrade
# suka
# parah
# maxim
# maxim
# hi
# aneh
# ribet
# sllu
# bagus
# bagusgampang
# butuh
# mohon
# aplikasi
# tolong
# aplikasi
# aplikasi
# loding
# harga
# update
# maxim
# maxim
# susah
# aplikasi
# driver
# susah
# lokasi
# ga
# mohon
# tolong
# kesal
# layan
# tolong
# sebenernya
# tolong
# history
# first
# aplikasi
# trf
# tolong
# aplikasi
# kembang
# aneh
# pake
# jalan
# harga
# temu
# titik
# maxim
# sen
# maaf
# tolong
# titik
# dapet
# driver
# bantu
# 1
# tarif
# dear
# aplikasi
# tlg
# aplikasi
# sopir
# aplikasi
# murah
# aplikasi
# murah
# kasih
# harga
# download
# maaf
# pesan
# tombol
# dapat
# udah
# mesen
# tolong
# maxim
# bonus
# merugikandrivernya
# aplikasi
# harga
# tolong
# mohon
# murah
# maxim
# sen
# niat
# susah
# aplikasi
# tolong
# enak
# gak
# kalo
# aplikasi
# mes
# transportasi
# biaya
# tolong
# mudah
# bagus
# tolong
# aplikasi
# murah
# maxim
# aplikasi
# tuh
# nyaman
# alamat
# abis
# sumpah
# harga
# parah
# bagus
# segi
# titik
# aplikasi
# tolong
# harga
# aplikasi
# tarif
# mohon
# rekomendasi
# tolong
# murah
# pas
# gak
# aplikasi
# maxim
# maps
# tolong
# harga
# niat
# order
# baik
# nan
# tolong
# tolong
# drivernya
# kasih
# tolong
# lengkap
# harga
# app
# maxim
# terima
# login
# wilayah
# aplikasi
# neng
# bagus
# harga
# promosi
# kali
# pas
# unggul
# driver
# biaya
# maxim
# google
# aplikasi
# order
# tolong
# user
# aplikasi
# maxim
# aplikasihnya
# parah
# aplikasi
# tolong
# moga
# ok
# hujan
# aplikasi
# aplikasi
# suka
# aneh
# aplikasi
# harga
# aplikasi
# cari
# driver
# harga
# murah
# kacau
# harga
# maps
# bagus
# tampil
# aplikasi
# harga
# order
# aplikasi
# maxim
# error
# tolong
# maxim
#             userName  score                at        content Kategori
# 0       Dina Resiana    2.0  27/11/2022 08.56         kecewa  Negatif
# 1        rahmi aulia    1.0  27/11/2022 08.23  alhamdulillah  Negatif
# 2          tavip vip    1.0  27/11/2022 06.10       aplikasi  Negatif
# 3    fitriyah hoirus    1.0  27/11/2022 05.54          maxim  Negatif
# 4  Supriatna Adikoko    1.0  27/11/2022 04.01          murah  Negatif

# %%
value_clean = value_clean.astype({'Kategori': 'category'})
value_clean = value_clean.astype({'content': 'string'})
value_clean.dtypes
# Out:
# userName      object
# score        float64
# at            object
# content       string
# Kategori    category
# dtype: object

# %%
#Proses TF-IDF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

tvec = CountVectorizer()
X_cVec = tvec.fit_transform(value_clean['content'].values.astype('U'))
print(X_cVec)
h_tfidf = TfidfTransformer()
x_tfidf = h_tfidf.fit_transform(X_cVec)
print(x_tfidf)
X = value_clean.content
Y = value_clean.Kategori
# Out:
#   (0, 73)	1
#   (1, 8)	1
#   (2, 14)	1
#   (3, 97)	1
#   (4, 106)	1
#   (5, 22)	1
#   (6, 35)	1
#   (7, 97)	1
#   (8, 178)	1
#   (9, 73)	1
#   (10, 60)	1
#   (11, 154)	1
#   (12, 40)	1
#   (13, 33)	1
#   (14, 14)	1
#   (15, 163)	1
#   (16, 107)	1
#   (17, 155)	1
#   (18, 14)	1
#   (19, 60)	1
#   (20, 155)	1
#   (21, 5)	1
#   (22, 97)	1
#   (23, 27)	1
#   (24, 19)	1
#   :	:
#   (475, 64)	1
#   (476, 14)	1
#   (477, 14)	1
#   (478, 147)	1
#   (479, 9)	1
#   (480, 14)	1
#   (481, 60)	1
#   (482, 14)	1
#   (483, 33)	1
#   (484, 40)	1
#   (485, 60)	1
#   (486, 106)	1
#   (487, 68)	1
#   (488, 60)	1
#   (489, 94)	1
#   (490, 19)	1
#   (491, 154)	1
#   (492, 14)	1
#   (493, 60)	1
#   (494, 117)	1
#   (495, 14)	1
#   (496, 97)	1
#   (497, 44)	1
#   (498, 163)	1
#   (499, 97)	1
#   (0, 73)	1.0
#   (1, 8)	1.0
#   (2, 14)	1.0
#   (3, 97)	1.0
#   (4, 106)	1.0
#   (5, 22)	1.0
#   (6, 35)	1.0
#   (7, 97)	1.0
#   (8, 178)	1.0
#   (9, 73)	1.0
#   (10, 60)	1.0
#   (11, 154)	1.0
#   (12, 40)	1.0
#   (13, 33)	1.0
#   (14, 14)	1.0
#   (15, 163)	1.0
#   (16, 107)	1.0
#   (17, 155)	1.0
#   (18, 14)	1.0
#   (19, 60)	1.0
#   (20, 155)	1.0
#   (21, 5)	1.0
#   (22, 97)	1.0
#   (23, 27)	1.0
#   (24, 19)	1.0
#   :	:
#   (475, 64)	1.0
#   (476, 14)	1.0
#   (477, 14)	1.0
#   (478, 147)	1.0
#   (479, 9)	1.0
#   (480, 14)	1.0
#   (481, 60)	1.0
#   (482, 14)	1.0
#   (483, 33)	1.0
#   (484, 40)	1.0
#   (485, 60)	1.0
#   (486, 106)	1.0
#   (487, 68)	1.0
#   (488, 60)	1.0
#   (489, 94)	1.0
#   (490, 19)	1.0
#   (491, 154)	1.0
#   (492, 14)	1.0
#   (493, 60)	1.0
#   (494, 117)	1.0
#   (495, 14)	1.0
#   (496, 97)	1.0
#   (497, 44)	1.0
#   (498, 163)	1.0
#   (499, 97)	1.0

# %%
#Proses eksekusi algoritma KFold
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

kf = KFold(n_splits=10)
X_array = x_tfidf.toarray()
def cross_val(estimator):
  acc = []
  pcs = []
  rec = []

  for train_index, test_index in kf.split(X_array, Y):
    X_train, X_test = X_array[train_index], X_array[test_index]
    y_train, y_test = Y[train_index], Y[test_index]

    model = estimator.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc.append(accuracy_score(y_test, y_pred))
    pcs.append(precision_score(y_test, y_pred, average='macro', zero_division=0))
    rec.append(recall_score(y_test, y_pred, average='macro', zero_division=0))
    rec.append(f1_score(y_test, y_pred, average='macro', zero_division=0))

    print(classification_report(y_test, y_pred, zero_division=0))
    print(f'Confusion Matrix:\n {confusion_matrix(y_test, y_pred)}')
    print('=================================================\n')

  print(f'Average Akurasi: {np.mean(acc)}')
  print(f'Average Presisi: {np.mean(pcs)}')
  print(f'Average Recall: {np.mean(rec)}')
  print(f'Average F1-Score: {np.mean(rec)}')

from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
cross_val(nb)
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.63      0.90      0.74        30
#      Positif       0.57      0.20      0.30        20
#
#     accuracy                           0.62        50
#    macro avg       0.60      0.55      0.52        50
# weighted avg       0.61      0.62      0.56        50
#
# Confusion Matrix:
#  [[27  3]
#  [16  4]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.65      0.87      0.74        30
#      Positif       0.60      0.30      0.40        20
#
#     accuracy                           0.64        50
#    macro avg       0.62      0.58      0.57        50
# weighted avg       0.63      0.64      0.61        50
#
# Confusion Matrix:
#  [[26  4]
#  [14  6]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.74      0.92      0.82        37
#      Positif       0.25      0.08      0.12        13
#
#     accuracy                           0.70        50
#    macro avg       0.49      0.50      0.47        50
# weighted avg       0.61      0.70      0.64        50
#
# Confusion Matrix:
#  [[34  3]
#  [12  1]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.72      0.97      0.82        34
#      Positif       0.75      0.19      0.30        16
#
#     accuracy                           0.72        50
#    macro avg       0.73      0.58      0.56        50
# weighted avg       0.73      0.72      0.66        50
#
# Confusion Matrix:
#  [[33  1]
#  [13  3]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.60      0.93      0.73        30
#      Positif       0.33      0.05      0.09        20
#
#     accuracy                           0.58        50
#    macro avg       0.46      0.49      0.41        50
# weighted avg       0.49      0.58      0.47        50
#
# Confusion Matrix:
#  [[28  2]
#  [19  1]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.65      0.91      0.76        33
#      Positif       0.25      0.06      0.10        17
#
#     accuracy                           0.62        50
#    macro avg       0.45      0.48      0.43        50
# weighted avg       0.52      0.62      0.53        50
#
# Confusion Matrix:
#  [[30  3]
#  [16  1]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.75      1.00      0.86        36
#      Positif       1.00      0.14      0.25        14
#
#     accuracy                           0.76        50
#    macro avg       0.88      0.57      0.55        50
# weighted avg       0.82      0.76      0.69        50
#
# Confusion Matrix:
#  [[36  0]
#  [12  2]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.85      0.98      0.91        41
#      Positif       0.67      0.22      0.33         9
#
#     accuracy                           0.84        50
#    macro avg       0.76      0.60      0.62        50
# weighted avg       0.82      0.84      0.81        50
#
# Confusion Matrix:
#  [[40  1]
#  [ 7  2]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.65      0.88      0.75        32
#      Positif       0.43      0.17      0.24        18
#
#     accuracy                           0.62        50
#    macro avg       0.54      0.52      0.49        50
# weighted avg       0.57      0.62      0.56        50
#
# Confusion Matrix:
#  [[28  4]
#  [15  3]]
# =================================================
#
#               precision    recall  f1-score   support
#
#      Negatif       0.60      0.94      0.73        31
#      Positif       0.00      0.00      0.00        19
#
#     accuracy                           0.58        50
#    macro avg       0.30      0.47      0.37        50
# weighted avg       0.37      0.58      0.46        50
#
# Confusion Matrix:
#  [[29  2]
#  [19  0]]
# =================================================
#
# Average Akurasi: 0.6679999999999999
# Average Presisi: 0.5844370298460368
# Average Recall: 0.5167464989704439
# Average F1-Score: 0.5167464989704439
